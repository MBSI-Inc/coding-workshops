# %% [markdown]
# # **Workshop #5 Worksheet**
#
# Welcome to Workshop #5, the final workshop for 2021! We're excited to share some fun and medically relevant problems for you to work through.
#
# Thank you for sticking with us this far.
#
# In the upcoming exercises, we've tried to be less explicit in our instructions to help you practise your problem-solving skills. Please reach out to your tutor or the answer sheet if you run into any difficulties.
#
# Also, feel free to add code cells to your worksheet as you work.
#
# Unless otherwise indicated as exercises, the code cells in this worksheet are illustrative examples which you can run.
#
# ---

# %% [markdown]
# # 1) Introduction
# So far we have covered different ways to manipulate data points such as numbers or strings. What if we encountered lots of data points grouped together? How do we store these data? How can they be manipulated? After workshops 5, we will be able to answer these two questions.
#
# In this workshop we will look at
#
#
# *   Principles of manipulating sequenced data
# *   Understanding how to use lists, tuples, dictionaries and their inbuilt methods in Python
# *   for loops part

# %% [markdown]
# ---
#
# # 2) Sequences
# A fundamental type of object in Python is the **sequence**. A sequence is like a numbered list of objects, kind of like a shopping list. The main sequences we will deal with in this course are strings, lists and tuples.

# %% [markdown]
# ## 2.1) Index
#
# We begin our exercises with a detailed look at strings. They are sequences of smaller strings, one for each character. The positions of characters within a string are numbered, starting with the first character being position number 0, and proceeding sequentially from left to right. For example, the different characters in the string `"MBSI Workshops"` are numbered as follows:

# %% [markdown]
# ![image.png](attachment:12434a28-56cf-4f2c-9cf1-97adfbf971ef.png)

# %% [markdown]
# To access a character at a particular position, we specify its position number inside square brackets. This technique is called **indexing**. The numeric position we specify inside the square brackets is called the **index**. Here is an example:

# %%
s = "MBSI Workshops"
print(s[2])
print(s[6])
print(s[9])

# %% [markdown]
# You can also create indices from right to left using negative values:

# %% [markdown]
# ![image.png](attachment:1dab4aed-8dda-4244-b007-5889b5feff85.png)

# %% [markdown]
# ### **Exercise 1**
#
# **Try recreate the previous three letters using negative indexing:**

# %%
# Exercise 1
s = "MBSI Workshops"

# Your code here

# %% [markdown]
# ## 2.2) Length
# What happens when we try to access an index that is outside of the string? Try running the following code:

# %%
print("MBSI Workshops"[17])

# %% [markdown]
# The index 17 is outside of the range of valid indices and an attempt to access an invalid index results in an error message. How do you find out the largest valid index in a string without having to count yourself? The largest valid index is one less than the length of the string (remember that we start counting from 0). Python has a built-in function for that purpose: the `len` function. The `len` function is used like this:

# %%
s = "MBSI Workshops"
n = len(s)
print(n)
print(len("Hello"))

# %% [markdown]
# ### **Exercise 2**
#
# **Print the maximum positive index and the minimum negative index (i.e. from right to left) of a given input, using the `len` function.**

# %%
# Exercise 2

my_string = input()

# %% [markdown]
# ## 2.2) Slice
#
# Now we are able to access individual characters in a string. What if we want to access a sequence of letters of a string like a word or a substring. We can do this by concatenating each individual character of this sequence. This, however, quickly becomes cumbersome if the substring is longer than a few characters.
#
# Python provides a convenient method to access a substring: you simply need to specify a start and an end index. This method is also known as **slicing**. For example, to access individual words in `"MBSI Workshops"`:

# %%
s = "MBSI Workshops"

# print "MBSI"
print(s[0] + s[1] + s[2] + s[3])  # you can concatenate individual characters
print(s[0:4])

# print "Work"
print(s[5:9])

# %% [markdown]
# Note that the slice is always made before the end index. So a slice [a:b] will only include character at index b-1 but not index b

# %% [markdown]
# By default, slicing assumes you will slice from the start of the string to the end of the string. If you are slicing from either end, you can just be lazy and do this:

# %%
s = "MBSI Workshops"

# print "MBSI"
print(s[:4])     # no initial index provided

# print "Workshops"
print(s[5:])     # no final index provided

# a slice from beginnning to end
print(s[:])

# %% [markdown]
# You can specify a third number which indicates the step size of your slice. For example, if you want every second element you can do this:

# %%
example = "0123456789"
# slice the string by stepping through every second character
print(example[0:10:2])
print(example[::2])

# you can specify a range with the steps
print(example[2:8:2])

# %% [markdown]
# You can also make your step size negative to change the direction of slicing. For example:

# %%
example = "0123456789"

# slice between index 8 to 4 from right to left:
print(example[8:4:-1])

# %% [markdown]
# ### **Exercise 3**
#
# **Can you predict the outcome of the following slices? Execute these codes to see if you have the correct prediction. Ask your tutors if you have any questions.**

# %%
"MBSI Workshops"[7:4]

# %%
"MBSI Workshops"[5:-1]

# %%
"MBSI Workshops"[1:5:2]

# %%
"MBSI Workshops"[:-2:6]

# %%
"MBSI Workshops"[5:2:-1]

# %%
"MBSI Workshops"[::-1]

# %% [markdown]
# ### **Exercise 4**
#
# **Can you produce `"975"` by slicing the example string below?**

# %%
# Exercise 4

example = "0123456789"

# %% [markdown]
# ## 2.3) Lists
#
# **Lists** are for storing sequences of any objects. You might, for example, want to store a list of numbers that you want to plot, a list of names of patients visiting the hospital, or a list of medications. Here are some examples of lists:

# %%
numbers = [2,3,5,6,9,14058496,-4]
cv_risk = ["hypertension", "diabetes", "hypercholesterolaemia", 60]
empty_list = []
list_of_lists = [numbers, cv_risk, empty_list]
print(list_of_lists)

# %% [markdown]
# An example of a bar plot using libraries and lists:

# %%
import matplotlib.pyplot as plt
names = ['group_a', 'group_b', 'group_c']
values = [20, 30, 100]

plt.bar(names, values)
plt.show()

# %% [markdown]
# ### **Exercise 5**
#
# **Let's try creating a list ourselves:**
#
# **Dr Whitehall is trying to create a plot on the cumulative probability of death for his patients over the decades. The probability values across year one to ten are as follows:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# He has got the plot template setup for you, are you able to fill in the values as lists?

# %%
# Exercise 5
import matplotlib.pyplot as plt

x_values =     # insert a list of x values here
y_values =     # insert a list of y values here

# code used for plotting, do not change
plt.plot(x_values, y_values)
plt.xlabel("Years of follow-up")
plt.ylabel("Cumulative Probability of Death (%)")
plt.show()

# %% [markdown]
# Once you have created a list, you can do all the things you have seen for strings as both are sequences (strings are sequences of characters, and lists are sequences of whatever objects you like).
#
# You can index them forwards and backwards by certain amounts:

# %%
my_patient = ['Lindsay', 'is', 75, "with", ["diabetes", "hypertension"]]
print(my_patient)
print(my_patient[1])
print(my_patient[-1])
print(my_patient[:1:-1])

# %% [markdown]
# You can index the lists/strings within a list by **double indexing**:

# %%
my_patient = ['Lindsay', 'is', 75, "with", ["diabetes", "hypertension"]]
print(my_patient[-1][0])
print(my_patient[-1][1])

# %% [markdown]
# Remember that we were able to concatenate strings (join them together with the `+` operator). We can also do this with lists:

# %%
my_string = "Dr" + " Stevens"
print(my_string)
my_list = [1, 2, 3] + [4, 5, 6]
print(my_list)

# %% [markdown]
# And remember what `*` does when applied to strings? It works analogously for lists:

# %%
my_string = "haha" * 5
print(my_string)
my_list = ["hypertension", "hypotension"] * 5
print(my_list)

# %% [markdown]
# And, of course, you can hit up against an **IndexError** if you try to access an element which isn't there:

# %%
my_patient = ['Lindsay', 'is', 75, "with", ["diabetes", "hypertension"]]
print(len(my_patient))
print(my_patient[5])
# Index error is a very common type of error!!!!

# %% [markdown]
# Better than strings, you can use index to **edit** individual elements in a list:

# %%
my_patient = ['Lindsay', 'is', 75, "with", ["diabetes", "hypertension"]]
my_patient[2] = 80
print(my_patient)
my_patient[:3] = ['John', 'Smith', 'is', 65]
print(my_patient)

# %% [markdown]
# ### **Exercise 6**
#
# **Complete a function, find_median, that returns the median from a list of sorted numbers. (In statistics, the median is the number in the middle of a sorted list. If the list has an even number of items, the median is the average of the middle two items)**
#
# **Hint: This is an exercise that consolidates all previous classes. You might need some if statements and the modulo operator (%)**

# %%
# Exercise 6

# %%
# Test your code for exercise 6 on the following test cases
testcase1 = [1,2,3,4,5,6]
testcase2 = [1,2,3,4,5,6,6]
print(find_median(testcase1)) # the median of testcase1 should be 3.5
print(find_median(testcase2)) # the median of testcase1 should be 4

# %% [markdown]
# **Alternatively, you can get the same function just using a Python library. Try import the library `statistics` and use its inbuilt function `median` to see if it produces the same result on the test cases.**

# %%
# Import statistics library and use built-in median function

# %% [markdown]
# ---
# # 3) Methods
#
# **Methods** are special functions that belong to specific data types. They are written and called a bit differently. An example of a method is the `upper()` method, which is specific to the string type. Try execute the example below, but have a guess at what will happen if you execute the code:

# %%
my_str = "mbsi workshops"
print(my_str)
print(my_str.upper())

# %% [markdown]
# Let's dissect that a bit though. `.upper()` is the method. It was called using the string object `my_str` by typing it after the string with a full-stop and some empty brackets. Just as was the case with functions, **method calls always require parentheses**, and if there are no (extra) arguments, the parentheses should be empty. However methods always get the object they're called from as an argument. So in this case, `.upper()` received `my_str` as its first argument automatically. It returns a new string which is an all-uppercase version of `my_str`.

# %% [markdown]
# ## 3.1) Useful list methods
# Python provides a number of useful methods for manipulating lists. In particular, many of the methods "mutate" the list they are applied to, meaning that if the list is saved as a variable, it will be changed permanently. The following are some notable examples of mutating list methods. Feel free to change the code and explore.

# %% [markdown]
# `append` adds a new item onto the end of a list:

# %%
patients = ['Leo', 'Britney', 'Angelo']
patients.append('Andy')
print(patients)

# %% [markdown]
# `pop` removes the final element from a (non-empty) list, or if called with a numeric argument, removes the element of that index:

# %%
pimples = ['arm', 'neck', 'forehead']
print(pimples.pop())
print(pimples)
print(pimples.pop(0))
print(pimples)

# %% [markdown]
# `insert` adds an item into a list at a specific index. (Remember that indices start at zero).

# %%
DCML = ['dorsal root nucleus', 'ventral posterior nucleus',
        'primary somatosensory cortex']
print(DCML)
DCML.insert(1, 'dorsal column')
print(DCML)

# %% [markdown]
# `remove` deletes the **first occurrence** of an item in a list. An error occurs if the item is not in the list.

# %%
medication = ['Hiprex', 'Stemetil', 'Vesicare', 'Hiprex']
medication.remove('Hiprex')
print(medication)

# %% [markdown]
# `clear` removes all items found in the list
#
# `del` removes a variable permanently

# %%
dementia = ["BV-FTD", "DAT", "VCI"]

del dementia[1]
print(dementia)

dementia.clear()
print(dementia) # list is emptied

# %% [markdown]
# ### **Exercise 7**
#
# **Are you able to add number 4 to the list of numbers using `append` and `+` (concatenation)? What is the difference?**

# %%
# use append here
my_list = [1,2,3]

# %%
# use concatenation here
my_list = [1,2,3]

# %% [markdown]
# We will not be practising all of the methods shown today, as it is quite a long worksheet. In reality some methods are more frequently used than others. Nevertheless, it is important to appreciate what methods are possible, and recognise when you've encountered problems that can be solved by methods. If you want a comprehensive list of list methods, I recommend having a look at [this table from W3School](https://www.w3schools.com/python/python_ref_list.asp) or [the official Python 3 documentations](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists).

# %% [markdown]
# ## 3.2) Finding an item
# `index` is a non-mutating method that returns the position of, again, the **first occurrence** of an item in a list, as seen in the following example, where the list contains multiple instances of `"Hib"`

# %%
vaccinations = ["HepB", "HepB", "RV", "Hib", "RV", "Hib"]
print(vaccinations.index("Hib"))

# %% [markdown]
# An error occurs if the argument to index is not in the list:

# %%
vaccinations = ["HepB", "HepB", "RV", "Hib", "RV", "Hib"]
print(vaccinations.index("HepC"))

# %% [markdown]
# To avoid bumping into an error everytime, we can check if the item we're searching for is in the sequence to begin with. We can do this using the `in` operator. Here is a function that searches for an item index in a sequence, and if the index is not found, it returns `None` instead of providing an error.

# %%
def advanced_index(lst, item):
    if item in lst: 
        # this line checks if the item is in the list input
        return lst.index(item)
    else:
        return None

vaccinations = ["HepB", "HepB", "RV", "Hib", "RV", "Hib"]
print(advanced_index(vaccinations, "HepC"))

# %% [markdown]
# ### **Exercise 8 （Optional）**
#
# **The hospital wants to write a natural language processor that picks up the temperature data from sentences written into physicians' notes. You are tasked to design a function `find_temp` that takes one sentence from the physician's note and returns the temperature mentioned in that sentence. If the sentence does not contain temperature information, your function should return `None`.**
#
# **Here are some examples of how your function should behave:**
#
# ```
# >>> get_temp("HR: 103, BP: 129/90, O2: 95%, RR: 26, T: 37.3")
# 37.3
# >>> get_temp("The patient is not responsive, her temperature is dropping to 37.2 degC.")
# 37.2
# >>> get_temp("Patient is febrile and hypertensive.")
# None
# ```
#
#
# **For this task, assume each input sentence contains at most one piece of information about temperature; temperatures are always represented in the format xx.x (i.e. three significant figures with one decimal places), and all temperature information are fully written in one of the following format:**
#
#
# *   T: xx.x
# *   xx.x degC
#
#
#
# **Hint: you can use the `advanced_index` function written above because both strings and lists are subjected to the `.index()` method**

# %%
# Exercise 8
def find_temp(sentence):

# %%
# Test your function for exercise 8 below
test1 = "HR: 103, BP: 129/90, O2: 95%, RR: 26, T: 37.3"
test2 = "The patient is not responsive, her temperature is dropping to 37.2 degC."
test3 = "patient is afabrile"

print(find_temp(test1)) # Should return 37.3
print(find_temp(test2)) # Should return 37.2
print(find_temp(test3)) # Should return None

# %% [markdown]
# The ability to find patterns in a given string is at the heart of natural language processing (NLP). This example shows a very primitive form of NLP where information can only be extracted from very well-defined language patterns. In reality there are several ways to express the same information, requiring more than billions of indices and if statements. Thus, using this method alone will never be sufficient for machines to understand daily languages.

# %% [markdown]
# ## 3.3) Sorting
#
# One list operation that you will find many applications for is sorting the elements. There are two ways of doing this, which will inevitably confuse you at some point because of the names being so similar: `.sort()` and `sorted`. You may have guessed from the way they are written, one of them is a method and the other is a function. We'll start with the `.sort()` **method**:

# %% [markdown]
# `.sort()` mutates the list by puting all items in the list into ascending numeric order

# %%
randlist1 = [4, 1, 3.0, 2, 5]
randlist1.sort()
print(randlist1)

# %% [markdown]
# `.reverse()` mutates the list by reversing the order of all items in the list

# %%
randlist2 = [4, 1, 3.0, 2, 5]
randlist2.reverse()
print(randlist2)

# %% [markdown]
# `sorted` takes a list and returns a new list with the elements in sorted *ascending* order (without mutating the original list).

# %%
randlist3 = [4, 1, 3.0, 2, 5]
print(sorted(randlist3))
print(randlist3)

# %% [markdown]
# You can use `sorted` to generate a new list in sorted *descending* order using an optional argument `reverse`

# %%
randlist = [4, 1, 3.0, 2, 5]
print(sorted(randlist, reverse=True))
print(randlist)

# %% [markdown]
# ### **Exercise 9**
#
# **Execute the following code to show a bar chart of Australian COVID19 testing statistics by state**

# %%
import matplotlib.pyplot as plt
states = ['ACT', 'NSW', 'NT', 'QLD', 'SA', 'TAS', 'VIC', 'WA']
test_number = [200796, 5680078, 180462, 2474437, 1279990, 213282, 5863187, 1084717]

plt.bar(states, test_number)
plt.xlabel("States")
plt.ylabel("Total tests conducted")
plt.show()

# %% [markdown]
# **Your task is to manipulate the `test_number` and `states` lists to identify the top 3 states in number of COVID19 tests conducted. By copying the template used above, plot these top 3 states in descending order of testing numbers.**
#
# ***Hint 1: both lists share the same index, so do not modify the original `test_number`, you will mess up its index correlation with `states`***

# %%
# Exercise 9

# %% [markdown]
# ## 3.4) Useful string methods
#
# String methods are different from list methods. They usually do not modify the string itself. Instead, they create a new output like a function.
#
# String methods are even more numerous than list methods. However, you don't need to know them all. Most of the commonly used string methods are embedded in the worksheet. Others worth mentioning include `.strip()`, `.upper()`, `.lower()`, `.isupper()`, `.islower()`, `.isdigit()`, `.isdecimal()`, etc. You can read about them [here](https://www.w3schools.com/python/python_ref_string.asp), or using [the official Python 3 documentation](https://docs.python.org/3/library/string.html). We will look at two examples in detail: `.split` and `.join`

# %% [markdown]
# `split` is a convenient way to turn a string into a list of words.

# %%
sniglet = 'Mitochondria is the powerhouse of the cell'
sniglet_words = sniglet.split()
print(sniglet_words)

# %% [markdown]
# By default, `split` segments up a string based on "whitespace" separators (space characters, tab characters, and line breaks), removing the separators in the process. It is possible to change this behaviour by specifying a separator in the argument to split, e.g.:

# %%
print("1,2,3".split(","))
print("l00k b4 U l3ap".split("b4"))

# %% [markdown]
# `.join` is like the reverse of `.split`, you will use both in the upcoming exercise. Test this function below or [read this tutorial](https://www.geeksforgeeks.org/join-function-python/) to see if you can figure out how to use `.join`. Being able to figure out functionality on your own is a very important skill in programming. Talk to your tutor if you need help.

# %%
# test .join here
testcase = ['Mitochondria', 'is', 'the', 'powerhouse', 'of', 'the', 'cell']
print("+".join(testcase))

# %% [markdown]
# ### **Exercise 10**
#
# **Write a function `reverse_sentence` that reverses the order of words in a sentence. The result should look like this:**
#
# ```
# >>> reverse_sentence("hello world")
# world hello
# >>> reverse_sentence("Mitochondria is the power house of the cell")
# cell the of house power the is Mitochondria
# ```

# %%
# Exercise 10

# %%
# test cases
print(reverse_sentence("Hello world"))
print(reverse_sentence("Mitochondria is the power house of the cell"))

# %% [markdown]
# ---
#
# # 4) Tuples and mutability

# %% [markdown]
# ### 4.1) Introduction to tuples
#
# **Tuples** are like the stubborn brother of lists: a tuple looks like a list, but it is *immutable*. This means you can't change it once you have created it.

# %%
my_tuple = (6, 2, 3, 4, 5)
my_tuple[0] = 2 # Error: Can't change any element of a tuple, as they are immutable

# %%
my_tuple = (6, 2, 3, 4, 5)
sorted(my_tuple) # returns a new sorted list, my_tuple is unchanged

# %% [markdown]
# Why would someone use tuples instead of lists? By being immutable, tuples have these advantages:
#
#   1. Tuples are faster than lists (not relevant at our level)
#   2. It makes your data stored in tuples safer, as they are not accidentally modified
#   3. Tuples can be used as dictionary keys, but not lists (Dictionaries covered later)

# %% [markdown]
# ## 4.2) Mutability vs immutability
#
# If the object is *mutable*, it can be modified (mutated) after creation, if it is *immutable*, it can't be modified after creation. If you are using *mutable* objects, beware of the following:
#
# **Example**

# %%
list1 = [1, 2, 3, 4, 5]   
list2 = list1                     # is list 2 is a copy of list one?
list2.append(6)
print("This is list1:", list1)
print("This is list2:", list2)

# %% [markdown]
# Notice how altering `list2` alters `list1` as well? This is because both `list1` and `list2` are referring to the same thing (a *mutable* list). Use `list1.copy()` to prevent this from happening.

# %%
list1 = [1, 2, 3, 4, 5]   
list2 = list1.copy()      # is list 2 is a copy of list one?
list2.append(6)
print("This is list1:", list1)
print("This is list2:", list2)

# %% [markdown]
# The case described above will happen when you use any mutable object:
#   - lists, sets, dictionaries(adding a new key:value set)
#
# This will not happen when using immutable objects:
#   - tuples, bool, int, float, string
#
# **Example**
#
# In the following example we are using strings but feel free to use any of the data types used above. Notice how what happened above to lists doesn't happen to strings and immutables.

# %%
str1 = "BMI"
str2 = str1
str2 += "f"
print("This is str1:", str1) # str1 is unchanged
print("This is str2:", str2) # str2 is changed

# %% [markdown]
# ### **Exercise 11 (Optional)**
#
# **Patients in the rehabilitation ward rotate between several activities outlined in a list. Each patient only does one activity per day, and different patients have different lists of activities.**
#
# **The nurses don't want to waste time figuring out the patients' activities everyday, so they want you to generate a new sequence everyday.**
#
# **Write a function `cycle()` that performs an "in-place" cycling of the elements of the activity list, moving each activity one position left in the list. Here "in place" means the operation should be performed by mutating the original list, and your function should not return anything. Note that you may assume that `input_list` is non-empty (i.e. contains at least one element)**
#
# **Some expected outputs**
# ```
# >>> today_activities = ("Carl", ["physio", "massage", "weight exercise", "pool", "psychologist"])
# >>> tomorrow_activities = cycle(today_activities)
# >>> today_activities
# ("Carl", ["physio", "massage", "weight exercise", "pool", "psychologist"])
# >>> tomorrow_activities
# ("Carl", ["massage", "weight exercise", "pool", "psychologist", "physio"])
# ```
#
# **Be careful of a mutable list inside an immutable tuple.**

# %%
# Exercise 11

# %%
# Test your cycle function from exercise 11
today_activities = ("Carl", ["physio", "massage", "weight exercise", "pool", "psychologist"])
tomorrow_activities = cycle(today_activities)
print(tomorrow_activities)

# %% [markdown]
# ---
#
# # 5) Dictionaries and Sets
#
# Let's have a look at some more interesting data structures

# %% [markdown]
# ## 5.1) Dictionary
#
# Now let's talk about a very useful data type: **dictionaries**. Dictionaries allow you to create mappings from **keys** to values. For example, you might use a dictionary to map patients to their corresponding conditions:

# %%
conditions = {'Jerry': 'Cystic Fibrosis',
    'Jack': 'Hypothermia',
    'Aaron': 'Gall Stones',
    'Lindsay': 'Jaundice',
    'Garry': 'COPD',
    'Amy': 'Coeliac'}

print(conditions["Jerry"])

# %% [markdown]
# The keys in the above dictionary are strings which represent the names of the patients. Each key maps to a value, which also happens to be a string (the patient's condition) in this case. In the general case, the keys and values can be of different **types**.
#
# Dictionary values are constructed using the curly brace characters `{  }`. As a special case, you can construct an empty dictionary using an opening and closing brace with nothing in between:
#
# `example_empty_dict = {}`
#
# In the above code, an empty dictionary is created and assigned to the variable `example_empty_dict`. Currently this dictionary contains no mappings, so it is fairly uninteresting. As you shall soon see, it is possible to add new mappings to an existing dictionary, so it can be useful to construct empty dictionaries and later add values as necessary.

# %% [markdown]
# ### 5.1.1) Dictionary indexing
#
# Like lists and strings, dictionaries are indexable. However, you index dictionaries by using a key value stored in the dictionary, it is different to indexing lists where you are using a position number. **Note that there isn't duplicate key values in dictionaries.**

# %%
conditions = {'Jerry': 'Cystic Fibrosis',
    'Jack': 'Hypothermia',
    'Aaron': 'Gall Stones',
    'Lindsay': 'Jaundice',
    'Garry': 'COPD',
    'Amy': 'Coeliac'}

print(conditions["Jerry"])
print(conditions["Aaron"])
print(conditions["Carl"]) # error, Carl is not in the dictionary, he's healthy
print(conditions[2]) # error, the dictionary doesn't use ordering

# %% [markdown]
# ### 5.1.2) Updating Dictionaries
#
# You can change the value which is associated with a key or add a new key and value pair to the dictionary using the assignment (`=`) operator:

# %%
conditions = {'Jerry': 'Cystic Fibrosis',
    'Jack': 'Hypothermia',
    'Aaron': 'Gall Stones',
    'Lindsay': 'Jaundice',
    'Garry': 'COPD',
    'Amy': 'Coeliac'} # Actually Amy has Ulcerative Colitis

# Let's change Amy's condition
conditions["Amy"] = "Ulcerative Colitis"

# Let's also add a new patient who has Hepatitis C
conditions["Irene"] = "Hepatitis C"

print(conditions["Amy"])
print(conditions["Irene"])

# %% [markdown]
# ### 5.1.3) Membership and Looking at the entire dictionary
#
# You can test if a key is present in a dictionary using the `in` operator.
#
# You can also get all the keys, values or `(key : value)` sets from the dictionary by using `.keys()`, `.values()` or `.items()`

# %%
conditions = {'Jerry': 'Cystic Fibrosis',
    'Jack': 'Hypothermia',
    'Aaron': 'Gall Stones',
    'Lindsay': 'Jaundice',
    'Garry': 'COPD',
    'Amy': 'Coeliac'}

# Check if Amy is a patient
print("Amy" in conditions)  # Try some other names

# Printing the dictionary
print(conditions.keys())    # All the keys
print(conditions.values())  # All the values
print(conditions.items())   # All the key:value pairs

# %% [markdown]
# #### **Exercise 12**
#
# **Write a function, check_condition, that checks if the patient has the right condition. It should return `True` if the named disease is the condition of the named patient and `False` otherwise. Here are the patients:**
#
#
# | Patient        | Condition    |
# | :------------- | :----------- |
# |  Karen   | Gastritis    |
# |  Kelly   | Peptic Ulcer |
# |  Karter  | Cholecystitis|
# |  Kevin   | Cirrhosis    |
# |  Kyle    | Coeliac      |
#
# **Your function should behave like this:**
# ```
# >>> check_condition('Karen', 'Gastritis')
# True
# >>> check_condition('Bob', 'Cirrhosis')
# False
# ```

# %%
# Exercise 12
patient_dict = {"Karen": "Gastritis",
                "Kelly": "Peptic Ulcer",
                "Karter": "Cholecystitis",
                "Kevin": "Cirrhosis",
                "Kyle": "Coeliac"}

def check_condition(name, disease):
    #Your code here

# %%
# Test your check_condition function
print(check_condition("Karen", "Gastritis"))
print(check_condition("Bob", "Cirrhosis"))

# %% [markdown]
# ## 5.2) Sets
#
# Finally, we introduce a useful but somewhat obscure data structure called a **set**. If you are familiar with sets in mathematics, it is exactly the same concept. For the rest of us, a set is like a list, but with *unique* elements, and *no order*.
#
# Sets also have operations that correspond to set operations in mathematics. Here is a reminder of those operations you learned in high school:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
set0 = {0, 1, 2, 2, 3, "a", "b", "b"}
print(set0) # A set will remove all duplicates

set1 = {2, 3, 4}
set2 = {2, 5}
print("set1-set2", set1 - set2)
print("set2-set1", set2 - set1)
print("Union: set2|set1", set2 | set1)
print("Intersection: set2 & set1", set2 & set1)

# %% [markdown]
# ### Exercise 13
#
# Today on the ward there have been 10 patients who have undergone surgery and 11 who have had a physiotherapy session. There are patients who have done both, how many patients are there in total on the ward? Use the provided sets to answer this.
#
# Surgery: Matt, Matthew, Sherry, Renaldo, Jessy, Mary, Jackson, Denis, Peter, John
#
# Physio: Ian, Jackson, Ash, Denis, Christie, Peter, Renaldo, Britt, Jessy, Mary, Betsy

# %%
# Exercise 13
surgerySet = {'Matt', 'Matthew', 'Sherry', 'Renaldo', 'Jessy', 'Mary', 'Jackson', 'Denis', 'Peter', 'John'}
physioSet = {'Ian', 'Jackson', 'Ash', 'Denis', 'Christie', 'Peter', 'Renaldo', 'Britt', 'Jessy', 'Mary', 'Betsy'}
# Your code here

# %% [markdown]
# ---
# # 6) `for` loops

# %% [markdown]
# ## 6.1) Introduction to `for` loops
#
# A typical `for` loop is of the following form:
#
# ```
# for <item> in <sequence>:
#     <instruction>
# ```
#
# Basically, there is a *predetermined* sequence, e.g. a list. For each item in the sequence, the `for` loop runs once. Therefore, the length of the sequence specifies the total number of "iterations" through the loop. Note that `<item>` actually becomes a variable (also known as an "iterator") that can be used within the loop.
#
# Confused? Let's see an example.
#
# **Example**

# %%
listOfNames = ["Alice", "Bob", "Charlie", "Dorothy"]

for name in listOfNames:
    print(f"Hi {name}!")

# %% [markdown]
# What happened above?
#
# For the first "iteration" of the loop, the value `"Alice"` is assigned to the variable `name`. The print function within the loop executes. Then, the loop repeats, but this time `"Bob"` is assigned to `name`. The print function executes again in this second iteration.
#
# This way, the loop runs four iterations; during each iteration, the items within `listOfNames` are assigned to `name` one-by-one.
#
# Note also that the commands `continue` and `break` work for `for` loops as well. In the case of `continue`, when the loop resets, the `<item>` variable moves on to the next item in the sequence.
#
# **Example**

# %%
listOfNames = ["Alice", "Bob", "Charlie", "Dorothy"]

for name in listOfNames:
    if name == "Bob":
        print("Not you Bob")
        continue    # skips saying Hi to Bob and moves on to Charlie
    print(f"Hi {name}!")

# %% [markdown]
# In this example, we use a `for` loop to iterate through a tuple of ice-cream flavours and print them.
#
# **Example**

# %%
ice_cream = ("chocolate", "strawberry", "vanilla")
for flavour in ice_cream:
    print(f"I like to eat {flavour} ice-cream!")

# %% [markdown]
# **Exercise 14: Lemonade Stand**
#
# **You and your friend have set up a lemonade stand. You earned 60 dollars on Monday, 105 dollars on Tuesday, 81 dollars on Wednesday, 54 dollars on Thursday, and 129 dollars on Friday. Use a `for` loop to calculate your average earnings for the week.**
#
# 1.   **Create a list containing your earnings in dollars for each weekday**
# 2.   **Use a `for` loop to calculate your total earnings for the week**
# 3.   **Calculate your average earnings by dividing the total earnings by the number of days you were open for business. Use the `len()` function so your code is adaptable if you decide to open for a different number of days per week.**
# 4.   **Print your average earnings to the screen**

# %%
# Exercise 14

# %% [markdown]
# ## 6.2) `for` loops and dictionaries
# `for` loops can also be used to iterate through dictionaries, even though they are not sequences as they are unordered. This is done by looping over a dictionary's *keys*, not its values or key:value pairs. You can retrieve the values stored in the dictionary via the keys.
#
# **Example**

# %%
capital_cities = {"Australia":"Canberra", "New Zealand":"Wellington", "China":"Beijing", "USA":"Washington DC", "Russia":"Moscow"}
for country in capital_cities: # country variable iterates over keys in capital_cities
    print(f"{country}: {capital_cities[country]}") # Prints key and value pairs

# %% [markdown]
# Alternatively, we can produce the same output as above by explicitly telling the `for` loop to iterate through the key:value pairs. We can use the `items()` method to return the key:value pairs in the dictionary as `(key, value)` tuples in a list. We can then loop over this list, making sure the iterator variable is now a tuple as well. The advantage of this method is that it's easier to reference values directly instead of using keys.
#
# **Example**

# %%
capital_cities = {"Australia":"Canberra", "New Zealand":"Wellington", "China":"Beijing", "USA":"Washington DC", "Russia":"Moscow"}
for country, city in capital_cities.items():
    print(f"{country}: {city}")

# %% [markdown]
# **Exercise 15: Favourite Books (Optional)**
#
# 1.   **Create a dictionary of your favourite childhood book series' and their authors**
# 2.   **Use a `for` loop to print out the key and value pairs using either of the methods above**

# %%
# Exercise 15

fave_books = {} # insert the book names with their authors

# %% [markdown]
# ## 6.3) Indexing using `range()`
# The `range()` function generates a sequence of integers. By default, the sequence starts from `0`, increments by `1` and stops *before* a specified integer `n` (i.e. the sequence goes up to `n-1`). The general form when using the `range()` function is `range(n)`. A more specific example is demonstrated below:
#
# **Example**

# %%
x = range(5) # Generates a sequence from 0 (default) to 4, incrementing by 1 (default)
for i in x:
    print(i)

# %% [markdown]
# **Example**

# %%
x = range(3, 9) # Generates a sequence from 3 to 8, incrementing by 1 (default)
print(x)
for i in x:
    print(i)

# %% [markdown]
# **Example**

# %%
statement = "I don't want to go to my Zoom lecture"
repetitions = range(10) # Generates a sequence from 0 to 9, incrementing by 1
for repeat in repetitions: 
    print(statement) # Prints the statement 10 times

# %% [markdown]
# Another reason why `range()` is useful when combined with `for` loops is *indexing*. If you loop through a sequence directly, the iterator variable will only store the values. In some cases however, we not only want to access the values in a sequence but also their indexed positions. `range()` solves this problem.
#
# Let's illustrate this with an example where we find the indices and characters in the string `"COVID-19"`.
#
# First, we find the number of characters in the string using the `len()` function.
#
# ```
# len("COVID-19")
# ```
#
# Next, we pass the length of the string into the the `range()` function to produce a sequence of string indices rather than characters.
#
# ```
# range(len("COVID-19"))
# ```
#
# Finally, we include this sequence in a `for` loop with `index` as the iterator variable. Now we can iterate through the string indices and print out both the index and the character. The character can be accessed using `str[index]`.
#
# **Example**

# %%
str = "COVID-19"

for index in range(len(str)):
    print(f"{index}: {str[index]}") # Printing index and character in string

# %% [markdown]
# **Exercise 16: Chest Pain**
#
# **A patient named Mr. AZ has presented to you with chest pain. Use a for loop to number your top 5 differential diagnoses for Mr. AZ's chest pain using `range()` and the provided list of diagnoses.**

# %%
# Exercise 16
diagnoses = ["acute myocardial infarction",
            "aortic dissection",
            "pulmonary embolism",
            "pneumothorax",
            "gastro-oesophageal reflux disease"]
print("My top 5 diagnoses for Mr. AZ's chest pain are: ")

# Your code here

# %% [markdown]
# ---
#
# # 3) Nested loops
# Similar to how we used nested conditional statements in Workshop 3, we can create a *nested loop* by putting a loop inside a loop.
#
# The "inner loop" is executed to completion once for every iteration of the "outer loop". You can include as many levels of nesting as you want, as long as you remember to indent properly.
#
# An example of a nested `for` loop is shown below, however, you can also have nested `while` loops or `for` loops within `while` loops and vice versa.
#
# **Example**

# %%
colours = ["red", "green", "blue"]
shapes = ["triangle", "square", "circle"]

for colour in colours: # Outer loop iterating through colours
    print(f'{colour} shapes:') # Print for each iteration of the outer loop
    for shape in shapes: # Nested inner loop iterating through shapes
        print(colour, shape) # Print combination of colour and shape for each iteration of the inner loop
    print('---------------') # Print for each iteration of the outer loop

# %% [markdown]
# ---
#
# # **Extension problem: Ward Manager**
#
# In this project, you will use loops (along with other techniques you've learned from previous workshops) to design a functional Electronic Medical Record (EMR)/ward management system that can:
#
#
# *   Admit patients
# *   Discharge patients
# *   Display patient information
#
# We'll do this step-by-step.

# %% [markdown]
# ## Part A)
#
# Before we attempt to create a functional EMR, let's take a step back. We will first create a way of storing some key patient information in a dictionary. For simplicity, we'll limit the information we store to:
# *  Patient name
# *  Patient age
# *  Patient gender
# *  Diagnosis
#
# **Task 1**
#
# **Using `input()` functions, prompt the user to enter details for each of the above questions. Store this information in a *dictionary*.**
#
# **As a guide, the dictionary should look like:**
# ```
# {"name":"Lindsay Brown", "age":"53", "gender":"F", "diagnosis":"pneumonia"}
# ```

# %%
# Task 1

# %% [markdown]
# ## Part B)
#
# Now that we have a way of storing information, let's move on and build the framework of our EMR system. Suppose our EMR has three separate functions:
#
# 1. Admit a new patient
# 2. Discharge a patient
# 3. View patient information
# 4. Display all patients' names
#
# Suppose our ward initially has 5 empty beds.
#
# The EMR runs as follows:
# *  It displays this menu to the user
# *  It prompts the user to select 1, 2, 3, 4 or 5
# *  It performs the appropriate task
# *  After completing this task, it returns to the menu and prompts the user for a new selection.
# *  If the user selects an option that isn't 1-5, print out "That is an invalid choice!" and prompt the user for a new selection.
#
# **Task 2**
#
# **The following flowchart is the scaffold for this EMR. Translate this flowchart into Python. Note that for now, we'll use `print("Option X selected)` as a placeholder for the tasks.**
#
# ![image.png](attachment:808c760d-634f-4b23-b8e7-a8c3d1858f6a.png)

# %%
# Task 2: Main scaffold
print("Welcome to Python Hospital.\n")
beds = [{}, {}, {}, {}, {}]

while True:
    print("What would you like to do?")
    print("\t1. Admit a patient")
    print("\t2. Discharge a patient")
    print("\t3. View patient information")
    print("\t4. View all patients")
    print("\t5. Exit")
    choice = input("Please make a choice (1,2,3,4,5): ")
    print()

    # Your code here

# %% [markdown]
# ## Part C)
#
# If the user selects Option 1, we want to admit a patient. This is done first checking to see if any beds are available. If there are no beds available, the EMR should tell you that the ward is full and return to the main menu for a new selection.
#
# If there are beds available, the EMR should prompt the user for key patient details exactly as you did in Task 1.
#
# Once you have generated the dictionary with patient information, you'll need to store the dictionary in the `beds` list. As an empty bed is represented by an empty dictionary in `beds`, you should overwrite the *first empty dictionary* with the dictionary corresponding to your new patient. This way, `beds` now contains the dictionary of your newly-admitted patient.
#
# **Task 3**
#
# **Think about how you would implement the above logic in Python. Then, return to the Task 2 scaffold code-cell above and replace the Option 1 placeholder with your (now functional) code.**

# %% [markdown]
# ## Part D)
#
# If the user selects Option 2, we want to discharge a patient. This is done by prompting the user to discharge a patient in Beds 1, 2, 3, 4 or 5.
#
# Once the user has made a bed choice, the EMR should then check to see if the bed is currently occupied.
# *  If it is not occupied, the EMR should tell the user that Bed X is currently empty.
# *  If the bed is occupied, the EMR should tell the user that Patient Y has been discharged. Then, the relevant dictionary item inside `beds` should be overwritten with an empty dictionary `{}` to represent the deletion of the patient.
#
# **Task 4**
#
# **Think about how you would implement the above logic in Python. Then, return to the Task 2 scaffold code-cell above and replace the Option 2 placeholder with your (now functional) code.**

# %% [markdown]
# # **Thanks for coming to the final Workshop! Please fill out the [feedback form](https://forms.gle/1GnsHhYUav7D281F8)**.
